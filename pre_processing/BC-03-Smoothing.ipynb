# %% [markdown]
# # Smoothing spatial data - Breast cancer

# %%
import scanpy as sc
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns

from tqdm import tqdm_notebook

from scipy import ndimage

# %%
sc.set_figure_params(dpi=100)

# %% [markdown]
# ## Read HD-ST data

# %%
adata = sc.read('results/hdst-breast-cancer.h5ad')
adata._sanitize()
adata
# Out:
# ... storing 'region' as categorical
# ... storing 'segment' as categorical
# AnnData object with n_obs × n_vars = 742440 × 23058
#     obs: 'region', 'segment', 'x', 'y'
#     var: 'gene_symbols', 'gene_ids'
#     uns: 'region_colors'
#     obsm: 'X_spatial', '5x'

# %%
adata_binned = sc.read('results/hdst-breast-cancer-lowres-5x.h5ad')
adata_binned
# Out:
# AnnData object with n_obs × n_vars = 62172 × 23058
#     obs: 'x', 'y', 'Fatty tissue', 'Fatty tissue;Fibrous tissue;Invasive cancer', 'Fatty tissue;Fibrous tissue;Invasive cancer;immune/lymphoid', 'Fatty tissue;Invasive cancer', 'Fatty tissue;Invasive cancer;immune/lymphoid', 'Fatty tissue;immune/lymphoid', 'Fibrous tissue', 'Fibrous tissue;Invasive cancer', 'Fibrous tissue;Invasive cancer;immune/lymphoid', 'Fibrous tissue;immune/lymphoid', 'Invasive cancer', 'Invasive cancer;immune/lymphoid', 'Unknown', 'immune/lymphoid', 'missing', 'total_counts'
#     var: 'gene_symbols', 'gene_ids'
#     obsm: 'X_spatial'

# %%
categories = adata.obs['region'].cat.categories.values
categories
# Out:
# array(['Fatty tissue', 'Fatty tissue;Fibrous tissue;Invasive cancer',
#        'Fatty tissue;Fibrous tissue;Invasive cancer;immune/lymphoid',
#        'Fatty tissue;Invasive cancer',
#        'Fatty tissue;Invasive cancer;immune/lymphoid',
#        'Fatty tissue;immune/lymphoid', 'Fibrous tissue',
#        'Fibrous tissue;Invasive cancer',
#        'Fibrous tissue;Invasive cancer;immune/lymphoid',
#        'Fibrous tissue;immune/lymphoid', 'Invasive cancer',
#        'Invasive cancer;immune/lymphoid', 'Unknown', 'immune/lymphoid',
#        'missing'], dtype=object)

# %%
best_cat = adata_binned.obs.loc[:, categories].values.argmax(axis=1)
valid_obs = adata_binned.obs.loc[:, categories].sum(1) > 0.0

adata_binned = adata_binned[valid_obs].copy()
best_cat = best_cat[valid_obs]

adata_binned.obs['region'] = categories[best_cat]
adata_binned.obs['region'] = adata_binned.obs['region'].astype('category')
adata_binned
# Out:
# AnnData object with n_obs × n_vars = 29950 × 23058
#     obs: 'x', 'y', 'Fatty tissue', 'Fatty tissue;Fibrous tissue;Invasive cancer', 'Fatty tissue;Fibrous tissue;Invasive cancer;immune/lymphoid', 'Fatty tissue;Invasive cancer', 'Fatty tissue;Invasive cancer;immune/lymphoid', 'Fatty tissue;immune/lymphoid', 'Fibrous tissue', 'Fibrous tissue;Invasive cancer', 'Fibrous tissue;Invasive cancer;immune/lymphoid', 'Fibrous tissue;immune/lymphoid', 'Invasive cancer', 'Invasive cancer;immune/lymphoid', 'Unknown', 'immune/lymphoid', 'missing', 'total_counts', 'region'
#     var: 'gene_symbols', 'gene_ids'
#     obsm: 'X_spatial'

# %%
def get_gene_images(adata, g, layer=None):
    if layer is None:
        return sp.sparse.coo_matrix((adata[:, g].X, (adata.obs.y, adata.obs.x))).toarray()
    else:
        return sp.sparse.coo_matrix((adata[:, g].layers[layer], (adata.obs.y, adata.obs.x))).toarray()

def smooth_adata(adata, layer_name, sigma=1):
    
    from scipy import ndimage

    if sp.sparse.issparse(adata.X):
        adata.layers[layer_name] = adata.X.toarray()
    else:
        adata.layers[layer_name] = adata.X.copy()
    
    for i, g in enumerate(tqdm_notebook(adata.var_names)):
        img = sp.sparse.coo_matrix((adata[:, g].X,(adata.obs.x, adata.obs.y))).toarray()
        img2 = ndimage.gaussian_filter(img, sigma)
        img2 = (img2/img2.max()) * img.max()
        adata.layers[layer_name][:, i] = img2[adata.obs.x, adata.obs.y]
  
    return adata

def smooth_adata_groupwise(adata, layer_name, cat_name, sigma=1):
    
    from scipy import ndimage

    if sp.sparse.issparse(adata.X):
        adata.layers[layer_name] = adata.X.toarray()
    else:
        adata.layers[layer_name] = adata.X.copy()
    
    for group in tqdm_notebook(adata.obs[cat_name].cat.categories):
        idx = np.where(adata.obs[cat_name] == group)[0]

        for i, g in enumerate(adata.var_names):
            img = sp.sparse.coo_matrix((adata[:, g].X[idx], (adata.obs.x[idx], adata.obs.y[idx]))).toarray()
            img2 = ndimage.gaussian_filter(img, sigma)
            img2 = (img2/img2.max()) * img.max() if img2.max() != 0 else img2
            adata.layers[layer_name][idx, i] = img2[adata.obs.x[idx], adata.obs.y[idx]]

    return adata

# %% [markdown]
# ### Compare group-wise and overall smoothing on binned data

# %%
sigma = 3
factor = 5

genes = ['EPCAM', 'ADIPOQ']
ad = adata_binned[:, genes].copy()

smooth_adata(ad, 'smooth_overall', sigma=sigma)
smooth_adata_groupwise(ad, 'smooth_groupwise', 'region', sigma=sigma)

plot_gene = 'EPCAM'

fig = plt.figure(figsize=(15, 10))

ax = plt.subplot(311)
plt.imshow(get_gene_images(adata_binned, plot_gene))
plt.title('raw image (%s gene)' % plot_gene)
ax.grid(False)

ax = plt.subplot(312)
plt.imshow(get_gene_images(ad, plot_gene, layer='smooth_overall'))
plt.title('smooth image (%s gene, %sx)' % (plot_gene, factor))
ax.grid(False)

ax = plt.subplot(313)
plt.imshow(get_gene_images(ad, plot_gene, layer='smooth_groupwise'))
plt.title('smooth image (%s gene, %sx, layerwise)' % (plot_gene, factor))
ax.grid(False)

plt.tight_layout()
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15), HTML(value='')))

# %% [markdown]
# ### Perform smoothing for binned datasets

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 742440 × 23058
#     obs: 'region', 'segment', 'x', 'y'
#     var: 'gene_symbols', 'gene_ids'
#     uns: 'region_colors'
#     obsm: 'X_spatial', '5x'

# %%
ad = sc.read('results/hdst-breast-cancer-lowres-%sx.h5ad' % 5)
ad
# Out:
# AnnData object with n_obs × n_vars = 62172 × 23058
#     obs: 'x', 'y', 'Fatty tissue', 'Fatty tissue;Fibrous tissue;Invasive cancer', 'Fatty tissue;Fibrous tissue;Invasive cancer;immune/lymphoid', 'Fatty tissue;Invasive cancer', 'Fatty tissue;Invasive cancer;immune/lymphoid', 'Fatty tissue;immune/lymphoid', 'Fibrous tissue', 'Fibrous tissue;Invasive cancer', 'Fibrous tissue;Invasive cancer;immune/lymphoid', 'Fibrous tissue;immune/lymphoid', 'Invasive cancer', 'Invasive cancer;immune/lymphoid', 'Unknown', 'immune/lymphoid', 'missing', 'total_counts'
#     var: 'gene_symbols', 'gene_ids'
#     obsm: 'X_spatial'

# %%
factors = (5, )
sigmas  = (0.5,)

for factor, sigma in zip(factors, sigmas):
    ad = sc.read('results/hdst-breast-cancer-lowres-%sx.h5ad' % factor)
    
    best_cat = ad.obs.loc[:, categories].values.argmax(axis=1)
    valid_obs = ad.obs.loc[:, categories].sum(1) > 0.0
    ad = ad[valid_obs].copy()
    best_cat = best_cat[valid_obs]

    ad.obs['region'] = categories[best_cat]
    ad.obs['region'] = ad.obs['region'].astype('category')
    
    #sc.pp.normalize_per_cell(ad)
    
    smooth_adata(ad, 'smooth_overall', sigma=sigma)

    plot_gene = 'EPCAM'

    fig = plt.figure(figsize=(15, 10))

    ax = plt.subplot(211)
    plt.imshow(get_gene_images(adata_binned, plot_gene))
    plt.title('raw image (%s gene)' % plot_gene)
    ax.grid(False)

    ax = plt.subplot(212)
    plt.imshow(get_gene_images(ad, plot_gene, layer='smooth_overall'))
    plt.title('smooth image (%s gene, %sx)' % (plot_gene, factor))
    ax.grid(False)

    plt.tight_layout()

    ad.write('results/hdst-breast-cancer-lowres-%sx-smooth-%ssigma.h5ad' % (factor, sigma))
# Out:
# HBox(children=(IntProgress(value=0, max=23058), HTML(value='')))
# ... storing 'region' as categorical

# %%
ad = sc.read('results/hdst-breast-cancer-lowres-5x-smooth-0.5sigma.h5ad')
ad.X = ad.layers['smooth_overall']
ad._inplace_subset_obs(ad.X.sum(1) > 0.0)

# %%
pd.DataFrame(ad.X, 
             columns=ad.var_names, 
             index=ad.obs_names).to_csv('results/hdst-breast-cancer-lowres-5x-smooth-0.5sigma.csv.gz', compression='gzip', index=False)

# %%
ad.obs.to_csv('results/hdst-breast-cancer-lowres-5x-smooth-0.5sigma-bins.csv.gz', compression='gzip', index=False)
